# %% [markdown]
# ## Project Scope

# %% [markdown]
# This project designs a data warehouse to analyze public service efficiency and citizen request
# patterns across two major U.S. cities: Boston and Washington, D.C.
#
# By integrating the Boston 311 Service Requests (2024) and DC 311 Service Requests (2024)
# datasets, the project enables:
#
# - Cross-city comparisons of government performance
# - Analysis of workload distribution across departments and service types
# - Exploration of geographic disparities using ZIP codes
#
# The data warehouse supports multi-dimensional analysis across time, department,
# request type, and location, helping evaluate how effectively different city agencies
# handle citizen-reported issues.

# %% [markdown]
# ## Business Questions

# %% [markdown]
# ## 1. What are the most common service types by city, and how do they change by month?
# - Identify the top service type for each month.
# - Compare Boston and Washington, D.C.
# - Examine whether seasonal or monthly patterns differ between the two cities.
#
#
# ## 2. Which service types have the longest average resolution times?
# - Compute the average resolution duration for each service type.
# - Compare slowest services between Boston and Washington, D.C.
# - Discuss whether certain categories consistently take longer in one city vs. the other.
#
#
# ## 3. How do service request volumes vary across ZIP codes within each city?
# - Break down request counts by geographic regions (ZIP code or ward).
# - Compare spatial distribution patterns between Boston and Washington, D.C.
# - Identify areas with unusually high or low request volumes.
#
#
# ## 4. Which ZIP codes have the lowest on-time performance, and does high request volume correlate with lower on-time rates?
# - For each city, compute on-time rates at the ZIP level.
# - Identify ZIP codes with the worst on-time performance.
# - Examine whether heavy request volume is associated with slower or delayed responses.
#
#
# ## 5. Which service types show the biggest response-time differences between Boston and Washington, D.C.?
# - Compare average resolution times between cities.
# - Identify services where performance gaps are the largest.
# - Discuss insights about efficiency differences across cities.

# %% [markdown]
# ## Extract

# %% [markdown]
# #### Data Overview

# %%
# Read Boston 311 Service Requests in 2024 Dataset 

import pandas as pd
Boston = pd.read_csv("Boston_311_Service_Requests2024.csv", dtype=str, low_memory=False)


# Print number of rows and columns
print(f"Rows: {Boston.shape[0]}")
print(f"Columns: {Boston.shape[1]}")

# Print column names 
print("\nColumn Names:")
print(Boston.columns.tolist())

# Show the first 5 rows
print("\nFirst 5 Rows:")
print(Boston.head())
# Out:
# Rows: 282836
# Columns: 30
#
# Column Names:
# ['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time', 'case_status', 'closure_reason', 'case_title', 'subject', 'reason', 'type', 'queue', 'department', 'submitted_photo', 'closed_photo', 'location', 'fire_district', 'pwd_district', 'city_council_district', 'police_district', 'neighborhood', 'neighborhood_services_district', 'ward', 'precinct', 'location_street_name', 'location_zipcode', 'latitude', 'longitude', 'geom_4326', 'source']
#
# First 5 Rows:
#   case_enquiry_id              open_dt        sla_target_dt  \
# 0    101005463183  2024-05-14 13:33:28  2024-05-17 04:30:00
# 1    101005463184  2024-05-14 13:33:53  2024-07-22 04:30:00
# 2    101005837387  2024-12-31 02:11:57  2025-01-01 03:30:00
# 3    101005287893  2024-02-07 04:01:41  2024-02-09 04:01:43
# 4    101005331785  2024-02-28 08:06:00  2024-02-29 08:06:25
#
#              closed_dt  on_time case_status  \
# 0  2024-05-15 02:58:54   ONTIME      Closed
# 1  2024-05-24 12:34:37   ONTIME      Closed
# 2                  NaN  OVERDUE        Open
# 3  2024-02-07 05:48:33   ONTIME      Closed
# 4  2024-03-04 09:07:57  OVERDUE      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : Wed May 15 06:58:54...
# 1  Case Closed. Closed date : Fri May 24 16:34:37...
# 2
# 3  Case Closed. Closed date : Wed Feb 07 10:48:33...
# 4  Case Closed. Closed date : 2024-03-04 14:07:57...
#
#                             case_title                            subject  \
# 0  Improper Storage of Trash (Barrels)            Public Works Department
# 1                     Graffiti Removal                Property Management
# 2                  Parking Enforcement  Transportation - Traffic Division
# 3  Improper Storage of Trash (Barrels)            Public Works Department
# 4                  Parking Enforcement  Transportation - Traffic Division
#
#                              reason  ...  neighborhood  \
# 0                  Code Enforcement  ...   East Boston
# 1                          Graffiti  ...    Dorchester
# 2  Enforcement & Abandoned Vehicles  ...  West Roxbury
# 3                  Code Enforcement  ...     South End
# 4  Enforcement & Abandoned Vehicles  ...    Dorchester
#
#   neighborhood_services_district     ward precinct  location_street_name  \
# 0                              1   Ward 1     0104  160-162 Liverpool St
# 1                              7  Ward 16     1604   1660 Dorchester Ave
# 2                             12  Ward 20     2011      416 Belgrade Ave
# 3                              6   Ward 5     0501    3 Saint Charles St
# 4                              9  Ward 17     1708          47 Torrey St
#
#   location_zipcode            latitude           longitude  \
# 0            02128   42.37387949518689  -71.03980037090297
# 1            02122  42.293928634128704  -71.06182167097816
# 2            02132   42.28578965220547  -71.14928081379779
# 3            02116  42.347129538504745  -71.07181050217132
# 4            02124   42.28737954696088   -71.0735636394372
#
#                                            geom_4326                source
# 0  0101000020E610000067D9DA168CC251C0813C8648DB2F...  Citizens Connect App
# 1  0101000020E610000042C2E1E2F4C351C06A7817749F25...  Citizens Connect App
# 2  0101000020E6100000A24B1DD18DC951C0FDE05CC19424...  Citizens Connect App
# 3  0101000020E61000007395138B98C451C03EAD9FBD6E2C...  Citizens Connect App
# 4  0101000020E6100000AE634444B5C451C03EDE5DDAC824...      Constituent Call
#
# [5 rows x 30 columns]

# %%
# Washington DC 311 Service Requests in 2024 Dataset


import pandas as pd
DC = pd.read_csv("DC_311_Service_Requests2024.csv", dtype=str, low_memory=False)

# Print number of rows and columns
print(f"Rows: {DC.shape[0]}")
print(f"Columns: {DC.shape[1]}")

# Print column names (header)
print("\nColumn Names:")
print(DC.columns.tolist())

# Show the first 5 rows
print("\nFirst 5 Rows:")
print(DC.head())
# Out:
# Rows: 422321
# Columns: 35
#
# Column Names:
# ['X', 'Y', 'SERVICEREQUESTID', 'STREETADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'WARD', 'SERVICECODE', 'SERVICECODEDESCRIPTION', 'SERVICETYPECODEDESCRIPTION', 'ORGANIZATIONACRONYM', 'SERVICECALLCOUNT', 'ADDDATE', 'RESOLUTIONDATE', 'SERVICEDUEDATE', 'SERVICEORDERDATE', 'STATUS_CODE', 'SERVICEORDERSTATUS', 'INSPECTIONFLAG', 'INSPECTIONDATE', 'INSPECTORNAME', 'PRIORITY', 'DETAILS', 'XCOORD', 'YCOORD', 'LATITUDE', 'LONGITUDE', 'MARADDRESSREPOSITORYID', 'GIS_ID', 'GLOBALID', 'CREATED', 'EDITED', 'SE_ANNO_CAD_DATA', 'OBJECTID']
#
# First 5 Rows:
#                   X                 Y SERVICEREQUESTID  \
# 0  398931.649999999         142784.18      24-00000013
# 1  397426.259999998  143264.026999999      24-00000033
# 2  403311.219999999  134980.440000001      24-00000045
# 3  406498.920000002  135695.989999998      24-00000046
# 4  398050.079999998         143079.59      24-00000059
#
#                              STREETADDRESS        CITY STATE ZIPCODE    WARD  \
# 0             5122 NEW HAMPSHIRE AVENUE NW  WASHINGTON    DC   20011  Ward 4
# 1  13TH STREET NW AND LONGFELLOW STREET NW  WASHINGTON    DC   20011  Ward 4
# 2                         3125 E STREET SE  WASHINGTON    DC   20019  Ward 7
# 3                         15 53RD PLACE SE  WASHINGTON    DC   20019  Ward 7
# 4                       5400 7TH STREET NW  WASHINGTON    DC   20011  Ward 4
#
#   SERVICECODE                  SERVICECODEDESCRIPTION  ...           YCOORD  \
# 0       S0031                         Bulk Collection  ...        142784.18
# 1    SPSTDAMA                    Traffic Safety Input  ...  143264.02702467
# 2       S0000  Abandoned Vehicle - On Public Property  ...        134980.44
# 3       S0311         Rodent Inspection and Treatment  ...        135695.99
# 4       S05SL        Streetlight Repair Investigation  ...        143079.59
#
#       LATITUDE     LONGITUDE MARADDRESSREPOSITORYID GIS_ID  \
# 0  38.95295847   -77.0123253                 259384    NaN
# 1   38.9572776  -77.02969441                 901770    NaN
# 2  38.88265423   -76.9618369                  39881    NaN
# 3  38.88908239  -76.92509065                  62678    NaN
# 4  38.95561809  -77.02249659                 250268    NaN
#
#                                  GLOBALID CREATED EDITED SE_ANNO_CAD_DATA  \
# 0  {0DDE2DA2-2F6A-647C-E063-792F520A6A54}     NaN    NaN              NaN
# 1  {0DE2FF5E-4ED1-278E-E063-792F520ABCD2}     NaN    NaN              NaN
# 2  {0DE3A04B-F3D2-0B73-E063-792F520ABBA9}     NaN    NaN              NaN
# 3  {0DE3A04B-F3D3-0B73-E063-792F520ABBA9}     NaN    NaN              NaN
# 4  {0DE44138-2C7A-1D36-E063-792F520A7FC1}     NaN    NaN              NaN
#
#    OBJECTID
# 0  11264889
# 1  11264890
# 2  11264891
# 3  11264892
# 4  11264893
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Check Duplicate

# %%
# Check how many duplicated rows exist

# Boston
duplicate_rows = Boston.duplicated().sum()
print(f"Number of duplicated rows in Boston: {duplicate_rows}")

# DC
duplicate_rows_dc = DC.duplicated().sum()
print(f"Number of duplicated rows in DC: {duplicate_rows_dc}")
# Out:
# Number of duplicated rows in Boston: 0
# Number of duplicated rows in DC: 0

# %%
# Check to see if any duplcated ID exist 

# Boston 
boston_key = "case_enquiry_id"
duplicate_keys_boston = Boston[Boston.duplicated(subset=[boston_key])]
print(f"Number of duplicated ID in Boston: {duplicate_keys_boston.shape[0]}")

# DC 
dc_key = "SERVICEREQUESTID"
duplicate_keys_dc = DC[DC.duplicated(subset=[dc_key])]
print(f"Number of duplicated ID in DC: {duplicate_keys_dc.shape[0]}")
# Out:
# Number of duplicated ID in Boston: 0
# Number of duplicated ID in DC: 0

# %% [markdown]
# #### Normalize Columns Name

# %%
# Boston 
Boston.columns = Boston.columns.str.strip().str.replace(' ', '_').str.lower()
print(Boston.columns.tolist()[:10])
# Out:
# ['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time', 'case_status', 'closure_reason', 'case_title', 'subject', 'reason']

# %%
# DC
DC.columns = DC.columns.str.strip().str.replace(' ', '_').str.lower()
print(DC.columns.tolist()[:10])
# Out:
# ['x', 'y', 'servicerequestid', 'streetaddress', 'city', 'state', 'zipcode', 'ward', 'servicecode', 'servicecodedescription']

# %% [markdown]
# #### Staging

# %%
# Save to Staging
Boston.to_csv("data/staging/Boston_staging.csv", index=False)
DC.to_csv("data/staging/DC_staging.csv", index=False)

# %%
# Read Staging
boston_staging = pd.read_csv("data/staging/Boston_staging.csv", dtype=str, low_memory=False)
dc_staging = pd.read_csv("data/staging/DC_staging.csv", dtype=str, low_memory=False)

print("Boston rows:", len(boston_staging))
print("DC rows:", len(dc_staging))
# Out:
# Boston rows: 282836
# DC rows: 422321

# %%
# Check Updated Boston Dataset
boston_staging.head()
# Out:
#   case_enquiry_id              open_dt        sla_target_dt  \
# 0    101005463183  2024-05-14 13:33:28  2024-05-17 04:30:00
# 1    101005463184  2024-05-14 13:33:53  2024-07-22 04:30:00
# 2    101005837387  2024-12-31 02:11:57  2025-01-01 03:30:00
# 3    101005287893  2024-02-07 04:01:41  2024-02-09 04:01:43
# 4    101005331785  2024-02-28 08:06:00  2024-02-29 08:06:25
#
#              closed_dt  on_time case_status  \
# 0  2024-05-15 02:58:54   ONTIME      Closed
# 1  2024-05-24 12:34:37   ONTIME      Closed
# 2                  NaN  OVERDUE        Open
# 3  2024-02-07 05:48:33   ONTIME      Closed
# 4  2024-03-04 09:07:57  OVERDUE      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : Wed May 15 06:58:54...
# 1  Case Closed. Closed date : Fri May 24 16:34:37...
# 2
# 3  Case Closed. Closed date : Wed Feb 07 10:48:33...
# 4  Case Closed. Closed date : 2024-03-04 14:07:57...
#
#                             case_title                            subject  \
# 0  Improper Storage of Trash (Barrels)            Public Works Department
# 1                     Graffiti Removal                Property Management
# 2                  Parking Enforcement  Transportation - Traffic Division
# 3  Improper Storage of Trash (Barrels)            Public Works Department
# 4                  Parking Enforcement  Transportation - Traffic Division
#
#                              reason  ...  neighborhood  \
# 0                  Code Enforcement  ...   East Boston
# 1                          Graffiti  ...    Dorchester
# 2  Enforcement & Abandoned Vehicles  ...  West Roxbury
# 3                  Code Enforcement  ...     South End
# 4  Enforcement & Abandoned Vehicles  ...    Dorchester
#
#   neighborhood_services_district     ward precinct  location_street_name  \
# 0                              1   Ward 1     0104  160-162 Liverpool St
# 1                              7  Ward 16     1604   1660 Dorchester Ave
# 2                             12  Ward 20     2011      416 Belgrade Ave
# 3                              6   Ward 5     0501    3 Saint Charles St
# 4                              9  Ward 17     1708          47 Torrey St
#
#   location_zipcode            latitude           longitude  \
# 0            02128   42.37387949518689  -71.03980037090297
# 1            02122  42.293928634128704  -71.06182167097816
# 2            02132   42.28578965220547  -71.14928081379779
# 3            02116  42.347129538504745  -71.07181050217132
# 4            02124   42.28737954696088   -71.0735636394372
#
#                                            geom_4326                source
# 0  0101000020E610000067D9DA168CC251C0813C8648DB2F...  Citizens Connect App
# 1  0101000020E610000042C2E1E2F4C351C06A7817749F25...  Citizens Connect App
# 2  0101000020E6100000A24B1DD18DC951C0FDE05CC19424...  Citizens Connect App
# 3  0101000020E61000007395138B98C451C03EAD9FBD6E2C...  Citizens Connect App
# 4  0101000020E6100000AE634444B5C451C03EDE5DDAC824...      Constituent Call
#
# [5 rows x 30 columns]

# %%
# Check Updated DC Dataset
dc_staging.head()
# Out:
#                   x                 y servicerequestid  \
# 0  398931.649999999         142784.18      24-00000013
# 1  397426.259999998  143264.026999999      24-00000033
# 2  403311.219999999  134980.440000001      24-00000045
# 3  406498.920000002  135695.989999998      24-00000046
# 4  398050.079999998         143079.59      24-00000059
#
#                              streetaddress        city state zipcode    ward  \
# 0             5122 NEW HAMPSHIRE AVENUE NW  WASHINGTON    DC   20011  Ward 4
# 1  13TH STREET NW AND LONGFELLOW STREET NW  WASHINGTON    DC   20011  Ward 4
# 2                         3125 E STREET SE  WASHINGTON    DC   20019  Ward 7
# 3                         15 53RD PLACE SE  WASHINGTON    DC   20019  Ward 7
# 4                       5400 7TH STREET NW  WASHINGTON    DC   20011  Ward 4
#
#   servicecode                  servicecodedescription  ...           ycoord  \
# 0       S0031                         Bulk Collection  ...        142784.18
# 1    SPSTDAMA                    Traffic Safety Input  ...  143264.02702467
# 2       S0000  Abandoned Vehicle - On Public Property  ...        134980.44
# 3       S0311         Rodent Inspection and Treatment  ...        135695.99
# 4       S05SL        Streetlight Repair Investigation  ...        143079.59
#
#       latitude     longitude maraddressrepositoryid gis_id  \
# 0  38.95295847   -77.0123253                 259384    NaN
# 1   38.9572776  -77.02969441                 901770    NaN
# 2  38.88265423   -76.9618369                  39881    NaN
# 3  38.88908239  -76.92509065                  62678    NaN
# 4  38.95561809  -77.02249659                 250268    NaN
#
#                                  globalid created edited se_anno_cad_data  \
# 0  {0DDE2DA2-2F6A-647C-E063-792F520A6A54}     NaN    NaN              NaN
# 1  {0DE2FF5E-4ED1-278E-E063-792F520ABCD2}     NaN    NaN              NaN
# 2  {0DE3A04B-F3D2-0B73-E063-792F520ABBA9}     NaN    NaN              NaN
# 3  {0DE3A04B-F3D3-0B73-E063-792F520ABBA9}     NaN    NaN              NaN
# 4  {0DE44138-2C7A-1D36-E063-792F520A7FC1}     NaN    NaN              NaN
#
#    objectid
# 0  11264889
# 1  11264890
# 2  11264891
# 3  11264892
# 4  11264893
#
# [5 rows x 35 columns]

# %%
print("\nColumn Names:")
print(boston_staging.columns.tolist())
# Out:
# Column Names:
# ['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time', 'case_status', 'closure_reason', 'case_title', 'subject', 'reason', 'type', 'queue', 'department', 'submitted_photo', 'closed_photo', 'location', 'fire_district', 'pwd_district', 'city_council_district', 'police_district', 'neighborhood', 'neighborhood_services_district', 'ward', 'precinct', 'location_street_name', 'location_zipcode', 'latitude', 'longitude', 'geom_4326', 'source']

# %%
print("\nColumn Names:")
print(dc_staging.columns.tolist())
# Out:
# Column Names:
# ['x', 'y', 'servicerequestid', 'streetaddress', 'city', 'state', 'zipcode', 'ward', 'servicecode', 'servicecodedescription', 'servicetypecodedescription', 'organizationacronym', 'servicecallcount', 'adddate', 'resolutiondate', 'serviceduedate', 'serviceorderdate', 'status_code', 'serviceorderstatus', 'inspectionflag', 'inspectiondate', 'inspectorname', 'priority', 'details', 'xcoord', 'ycoord', 'latitude', 'longitude', 'maraddressrepositoryid', 'gis_id', 'globalid', 'created', 'edited', 'se_anno_cad_data', 'objectid']

# %% [markdown]
# #### Only Select Necessary Columns

# %% [raw]
# New Naming           |Boston Source           |DC Source
# case_id	             |case_enquiry_id	      |servicerequestid
# request_open_date    |open_dt	              |adddate
# request_closed_date	 |closed_dt	              |resolutiondate
# sla_target_dt	     |sla_target_dt	          |serviceduedate
# case_status	         |case_status             |serviceorderstatus
# on_time_flag	     |on_time	              |can be derived later using SLA
# service_name	     |case_title	          |servicetypecodedescription
# service_type	     |type 	                  |servicecodedescription
# department_name	     |department	          |organizationacronym
# street_address	     |location_street_name	  |streetaddress
# zipcode	             |location_zipcode	      |zipcode
# ward	             |ward	                  |ward
# latitude	         |latitude	              |latitude
# longitude            |longitude	              |longitude
# city	             |fixed as “Boston”	      |city
# state                |fixed as “MA”           |state

# %% [raw]
# # Only keep Boston's Necessary Columns
# boston_keep = [
#     "case_enquiry_id", "open_dt", "closed_dt", "sla_target_dt",
#     "on_time", "case_status", "type","case_title", "department",
#     "ward", "location_street_name", "location_zipcode",
#     "latitude", "longitude"
# ]
#
# # Only keep DC's Necessary Columns
# dc_keep = [
#     "servicerequestid", "adddate", "resolutiondate", "serviceduedate",
#     "serviceorderstatus",
#     "servicecodedescription", "servicetypecodedescription",
#     "organizationacronym",
#     "city", "state", "zipcode", "ward", "streetaddress",
#     "latitude", "longitude"
# ]
#
# boston_cols = [c for c in boston_keep if c in boston_staging.columns]
# dc_cols = [c for c in dc_keep if c in dc_staging.columns]
#
# boston_sub = boston_staging[boston_cols].copy()
# dc_sub     = dc_staging[dc_cols].copy()

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np

engine = create_engine(f"postgresql://postgres:Chaney0616%%%@localhost:5432/Term_Project")


from sqlalchemy import text


# Create the "config" schema if it does not already exist
with engine.begin() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS config;"))



# Create the keep_columns table
with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS config.keep_columns (
            source_system TEXT,
            column_name TEXT
        );
    """))

# Clear old rows to avoid duplicates when we re-run the notebook
with engine.begin() as conn:
    conn.execute(text("DELETE FROM config.keep_columns;"))



# Insert the “Necessary Columns” lists for Boston and DC
with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO config.keep_columns VALUES

        -- Boston Necessary Columns 
        ('BOSTON', 'case_enquiry_id'),
        ('BOSTON', 'open_dt'),
        ('BOSTON', 'closed_dt'),
        ('BOSTON', 'sla_target_dt'),
        ('BOSTON', 'on_time'),
        ('BOSTON', 'case_status'),
        ('BOSTON', 'type'),
        ('BOSTON', 'case_title'),
        ('BOSTON', 'department'),
        ('BOSTON', 'ward'),
        ('BOSTON', 'location_street_name'),
        ('BOSTON', 'location_zipcode'),
        ('BOSTON', 'latitude'),
        ('BOSTON', 'longitude'),

        -- DC Necessary Columns 
        ('DC', 'servicerequestid'),
        ('DC', 'adddate'),
        ('DC', 'resolutiondate'),
        ('DC', 'serviceduedate'),
        ('DC', 'serviceorderstatus'),
        ('DC', 'servicecodedescription'),
        ('DC', 'servicetypecodedescription'),
        ('DC', 'organizationacronym'),
        ('DC', 'city'),
        ('DC', 'state'),
        ('DC', 'zipcode'),
        ('DC', 'ward'),
        ('DC', 'streetaddress'),
        ('DC', 'latitude'),
        ('DC', 'longitude');
    """))

# %%
pd.read_sql("SELECT * FROM config.keep_columns", engine)
# Out:
#    source_system                 column_name
# 0         BOSTON             case_enquiry_id
# 1         BOSTON                     open_dt
# 2         BOSTON                   closed_dt
# 3         BOSTON               sla_target_dt
# 4         BOSTON                     on_time
# 5         BOSTON                 case_status
# 6         BOSTON                        type
# 7         BOSTON                  case_title
# 8         BOSTON                  department
# 9         BOSTON                        ward
# 10        BOSTON        location_street_name
# 11        BOSTON            location_zipcode
# 12        BOSTON                    latitude
# 13        BOSTON                   longitude
# 14            DC            servicerequestid
# 15            DC                     adddate
# 16            DC              resolutiondate
# 17            DC              serviceduedate
# 18            DC          serviceorderstatus
# 19            DC      servicecodedescription
# 20            DC  servicetypecodedescription
# 21            DC         organizationacronym
# 22            DC                        city
# 23            DC                       state
# 24            DC                     zipcode
# 25            DC                        ward
# 26            DC               streetaddress
# 27            DC                    latitude
# 28            DC                   longitude

# %%
# Read the keep_columns rules from the config table
keep_rules = pd.read_sql("SELECT * FROM config.keep_columns", engine)

# Split rules into Boston and DC lists
boston_keep = keep_rules[keep_rules["source_system"] == "BOSTON"]["column_name"].tolist()
dc_keep     = keep_rules[keep_rules["source_system"] == "DC"]["column_name"].tolist()


# Filter the staging data using the rules
boston_cols = [c for c in boston_keep if c in boston_staging.columns]
dc_cols     = [c for c in dc_keep if c in dc_staging.columns]

# Subset the staging data according to the config rules
boston_sub = boston_staging[boston_cols].copy()
dc_sub     = dc_staging[dc_cols].copy()

# Display Boston subset
boston_sub
# Out:
#        case_enquiry_id              open_dt            closed_dt  \
# 0         101005463183  2024-05-14 13:33:28  2024-05-15 02:58:54
# 1         101005463184  2024-05-14 13:33:53  2024-05-24 12:34:37
# 2         101005837387  2024-12-31 02:11:57                  NaN
# 3         101005287893  2024-02-07 04:01:41  2024-02-07 05:48:33
# 4         101005331785  2024-02-28 08:06:00  2024-03-04 09:07:57
# ...                ...                  ...                  ...
# 282831    101005838178  2024-12-31 17:42:59                  NaN
# 282832    101005838183  2024-12-31 17:49:30                  NaN
# 282833    101005287764  2024-02-07 02:28:46  2024-02-07 02:37:35
# 282834    101005238419  2024-01-05 15:11:32  2024-01-17 09:11:18
# 282835    101005734154  2024-10-15 21:23:55  2024-10-16 01:48:49
#
#               sla_target_dt  on_time case_status  \
# 0       2024-05-17 04:30:00   ONTIME      Closed
# 1       2024-07-22 04:30:00   ONTIME      Closed
# 2       2025-01-01 03:30:00  OVERDUE        Open
# 3       2024-02-09 04:01:43   ONTIME      Closed
# 4       2024-02-29 08:06:25  OVERDUE      Closed
# ...                     ...      ...         ...
# 282831  2025-01-02 03:30:00  OVERDUE        Open
# 282832  2025-01-02 03:30:00  OVERDUE        Open
# 282833  2024-02-08 03:30:00   ONTIME      Closed
# 282834  2024-01-09 03:30:00  OVERDUE      Closed
# 282835  2024-10-17 04:30:00   ONTIME      Closed
#
#                                        type  \
# 0       Improper Storage of Trash (Barrels)
# 1                          Graffiti Removal
# 2                       Parking Enforcement
# 3       Improper Storage of Trash (Barrels)
# 4                       Parking Enforcement
# ...                                     ...
# 282831                  Parking Enforcement
# 282832                  Parking Enforcement
# 282833                        CE Collection
# 282834                  Parking Enforcement
# 282835                        CE Collection
#
#                                  case_title department     ward  \
# 0       Improper Storage of Trash (Barrels)       PWDx   Ward 1
# 1                          Graffiti Removal       PROP  Ward 16
# 2                       Parking Enforcement       BTDT  Ward 20
# 3       Improper Storage of Trash (Barrels)       PWDx   Ward 5
# 4                       Parking Enforcement       BTDT  Ward 17
# ...                                     ...        ...      ...
# 282831                  Parking Enforcement       BTDT        7
# 282832                  Parking Enforcement       BTDT   Ward 7
# 282833                        CE Collection       PWDx   Ward 4
# 282834                  Parking Enforcement       BTDT       19
# 282835                        CE Collection       PWDx        5
#
#                          location_street_name location_zipcode  \
# 0                        160-162 Liverpool St            02128
# 1                         1660 Dorchester Ave            02122
# 2                            416 Belgrade Ave            02132
# 3                          3 Saint Charles St            02116
# 4                                47 Torrey St            02124
# ...                                       ...              ...
# 282831   INTERSECTION Gold St & Dorchester St              NaN
# 282832                                49 G St            02127
# 282833                        26 Clarendon St            02116
# 282834  INTERSECTION Centre St & Burroughs St              NaN
# 282835     INTERSECTION Irving St & Revere St              NaN
#
#                   latitude           longitude
# 0        42.37387949518689  -71.03980037090297
# 1       42.293928634128704  -71.06182167097816
# 2        42.28578965220547  -71.14928081379779
# 3       42.347129538504745  -71.07181050217132
# 4        42.28737954696088   -71.0735636394372
# ...                    ...                 ...
# 282831   42.33471436565981   -71.0472890926374
# 282832   42.33429950357856  -71.04438046918051
# 282833    42.3450695401875   -71.0726605082934
# 282834  42.311575806821814  -71.11439697757105
# 282835   42.35956847484959  -71.06636036036686
#
# [282836 rows x 14 columns]

# %%
# Display DC subset
dc_sub
# Out:
#        servicerequestid                 adddate          resolutiondate  \
# 0           24-00000013  2024/01/01 07:02:11+00  2024/01/09 19:41:49+00
# 1           24-00000033  2024/01/01 12:46:57+00  2024/01/01 12:54:05+00
# 2           24-00000045  2024/01/01 13:39:26+00  2024/01/05 13:46:58+00
# 3           24-00000046  2024/01/01 13:40:25+00  2024/01/02 15:36:35+00
# 4           24-00000059  2024/01/01 14:17:28+00  2024/01/04 12:59:13+00
# ...                 ...                     ...                     ...
# 422316      24-00755508  2024/12/29 08:45:04+00  2025/02/27 17:01:22+00
# 422317      24-00619958  2024/10/19 04:10:27+00  2025/03/20 18:17:28+00
# 422318      25-00312525  2024/12/28 15:52:47+00  2025/05/22 13:46:03+00
# 422319      25-00312549  2024/04/04 13:48:29+00  2025/05/22 13:50:36+00
# 422320      25-00312503  2024/08/27 12:59:10+00  2025/05/22 13:40:44+00
#
#                 serviceduedate    serviceorderstatus  \
# 0       2024/01/10 04:59:00+00                Closed
# 1       2024/01/02 12:46:57+00                Closed
# 2       2024/01/18 13:39:26+00              Canceled
# 3       2024/01/08 13:40:25+00                Closed
# 4       2024/01/10 14:17:28+00                Closed
# ...                        ...                   ...
# 422316  2025/02/08 04:59:00+00                Closed
# 422317  2025/07/02 04:10:27+00                Closed
# 422318  2025/03/26 15:52:46+00  Closed (Transferred)
# 422319  2024/06/27 13:48:29+00  Closed (Transferred)
# 422320  2024/11/22 12:59:10+00  Closed (Transferred)
#
#                         servicecodedescription  \
# 0                              Bulk Collection
# 1                         Traffic Safety Input
# 2       Abandoned Vehicle - On Public Property
# 3              Rodent Inspection and Treatment
# 4             Streetlight Repair Investigation
# ...                                        ...
# 422316                    Scheduled Yard Waste
# 422317                            Tree Removal
# 422318         Public Space Litter Can Removal
# 422319         Public Space Litter Can Removal
# 422320         Public Space Litter Can Removal
#
#                                servicetypecodedescription organizationacronym  \
# 0               SWMA- Solid Waste Management Admistration                 DPW
# 1                            Department of Transportation                DDOT
# 2       PEMA- Parking Enforcement Management Administr...                 DPW
# 3                               DOH- Department Of Health                 DOH
# 4                Transportation Operations Administration                DDOT
# ...                                                   ...                 ...
# 422316        SWMA- Solid Waste Management Administration                 DPW
# 422317                                    Urban Forrestry                DDOT
# 422318        SWMA- Solid Waste Management Administration                 DPW
# 422319        SWMA- Solid Waste Management Administration                 DPW
# 422320        SWMA- Solid Waste Management Administration                 DPW
#
#               city state zipcode    ward  \
# 0       WASHINGTON    DC   20011  Ward 4
# 1       WASHINGTON    DC   20011  Ward 4
# 2       WASHINGTON    DC   20019  Ward 7
# 3       WASHINGTON    DC   20019  Ward 7
# 4       WASHINGTON    DC   20011  Ward 4
# ...            ...   ...     ...     ...
# 422316  WASHINGTON    DC   20003  Ward 6
# 422317  WASHINGTON    DC   20002  Ward 5
# 422318  WASHINGTON    DC   20002  Ward 5
# 422319  WASHINGTON    DC   20009  Ward 1
# 422320  WASHINGTON    DC   20019  Ward 7
#
#                                   streetaddress     latitude     longitude
# 0                  5122 NEW HAMPSHIRE AVENUE NW  38.95295847   -77.0123253
# 1       13TH STREET NW AND LONGFELLOW STREET NW   38.9572776  -77.02969441
# 2                              3125 E STREET SE  38.88265423   -76.9618369
# 3                              15 53RD PLACE SE  38.88908239  -76.92509065
# 4                            5400 7TH STREET NW  38.95561809  -77.02249659
# ...                                         ...          ...           ...
# 422316                       951 14TH STREET SE  38.87881314  -76.98579088
# 422317                     1141 MORSE STREET NE  38.90409809  -76.99109961
# 422318                     1211 ORREN STREET NE  38.90243367  -76.98560506
# 422319           W STREET NW AND 12TH STREET NW  38.91918147  -77.02808424
# 422320              3306 EAST CAPITOL STREET NE  38.89009128  -76.95968759
#
# [422321 rows x 15 columns]

# %% [raw]
# # Boston rename mapping
# boston_rename = {
#     "case_enquiry_id": "case_id",
#     "open_dt": "request_open_date",
#     "closed_dt": "request_closed_date",
#     "sla_target_dt": "sla_target_dt",
#     "on_time": "on_time_flag",
#     "case_status": "case_status",
#     "case_title": "service_name",
#     "type": "service_type",
#     "department": "department_name",
#     "location_street_name": "street_address",
#     "location_zipcode": "zipcode",
#     "ward": "ward",
#     "latitude": "latitude",
#     "longitude": "longitude"
# }
#
# boston_sub["city"] = "Boston"
# boston_sub["state"] = "MA"
#
# # DC rename mapping
# dc_rename = {
#     "servicerequestid": "case_id",
#     "adddate": "request_open_date",
#     "resolutiondate": "request_closed_date",
#     "serviceduedate": "sla_target_dt",
#     "serviceorderstatus": "case_status",
#     "servicecodedescription": "service_name",
#     "servicetypecodedescription": "service_type",
#     "organizationacronym": "department_name",
#     "streetaddress": "street_address",
#     "zipcode": "zipcode",
#     "ward": "ward",
#     "latitude": "latitude",
#     "longitude": "longitude",
#     "city": "city",
#     "state": "state"
# }
#
# boston_sub.rename(columns=boston_rename, inplace=True)
# dc_sub.rename(columns=dc_rename, inplace=True)

# %%
from sqlalchemy import text

# Create the config schema 
with engine.begin() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS config;"))

# Create the column_mapping table
with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS config.column_mapping (
            source_system TEXT,
            raw_column    TEXT,
            unified_column TEXT
        );
    """))

# Clear the table before inserting new mapping rules
with engine.begin() as conn:
    conn.execute(text("DELETE FROM config.column_mapping;"))

# Insert mapping rules for Boston and DC
with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO config.column_mapping (source_system, raw_column, unified_column) VALUES
        -- Boston
        ('BOSTON','case_enquiry_id','case_id'),
        ('BOSTON','open_dt','request_open_date'),
        ('BOSTON','closed_dt','request_closed_date'),
        ('BOSTON','sla_target_dt','sla_target_dt'),
        ('BOSTON','on_time','on_time_flag'),
        ('BOSTON','case_status','case_status'),
        ('BOSTON','type','service_type'),
        ('BOSTON','case_title','service_name'),
        ('BOSTON','department','department_name'),
        ('BOSTON','location_street_name','street_address'),
        ('BOSTON','location_zipcode','zipcode'),
        ('BOSTON','ward','ward'),
        ('BOSTON','latitude','latitude'),
        ('BOSTON','longitude','longitude'),

        -- DC
        ('DC','servicerequestid','case_id'),
        ('DC','adddate','request_open_date'),
        ('DC','resolutiondate','request_closed_date'),
        ('DC','serviceduedate','sla_target_dt'),
        ('DC','serviceorderstatus','case_status'),
        ('DC','servicecodedescription','service_name'),
        ('DC','servicetypecodedescription','service_type'),
        ('DC','organizationacronym','department_name'),
        ('DC','streetaddress','street_address'),
        ('DC','zipcode','zipcode'),
        ('DC','ward','ward'),
        ('DC','latitude','latitude'),
        ('DC','longitude','longitude'),
        ('DC','city','city'),
        ('DC','state','state');
    """))

# %%
mapping_df = pd.read_sql("SELECT * FROM config.column_mapping", engine)

# Function: apply_mapping(); Renames columns based on the mapping rules
def apply_mapping(df, source):
    rules = mapping_df[mapping_df["source_system"] == source]

    rename_dict = {
        row["raw_column"]: row["unified_column"]
        for _, row in rules.iterrows()
        if row["raw_column"] in df.columns
    }

    return df.rename(columns=rename_dict)

# Add missing city/state for Boston (DC already has them)
boston_sub["city"] = "Boston"
boston_sub["state"] = "MA"

# Apply unified column mapping to both datasets
boston_sub = apply_mapping(boston_sub, "BOSTON")
dc_sub     = apply_mapping(dc_sub, "DC")


# Use of IA
# I used ChatGPT to help me transform my earlier hard-coded column-renaming logic into a reusable function. 
# Specifically, ChatGPT assisted me in designing the apply_mapping() function, 
# which reads the mapping rules from the database and automatically renames columns for each source system.

# %%
boston_sub
# Out:
#              case_id    request_open_date  request_closed_date  \
# 0       101005463183  2024-05-14 13:33:28  2024-05-15 02:58:54
# 1       101005463184  2024-05-14 13:33:53  2024-05-24 12:34:37
# 2       101005837387  2024-12-31 02:11:57                  NaN
# 3       101005287893  2024-02-07 04:01:41  2024-02-07 05:48:33
# 4       101005331785  2024-02-28 08:06:00  2024-03-04 09:07:57
# ...              ...                  ...                  ...
# 282831  101005838178  2024-12-31 17:42:59                  NaN
# 282832  101005838183  2024-12-31 17:49:30                  NaN
# 282833  101005287764  2024-02-07 02:28:46  2024-02-07 02:37:35
# 282834  101005238419  2024-01-05 15:11:32  2024-01-17 09:11:18
# 282835  101005734154  2024-10-15 21:23:55  2024-10-16 01:48:49
#
#               sla_target_dt on_time_flag case_status  \
# 0       2024-05-17 04:30:00       ONTIME      Closed
# 1       2024-07-22 04:30:00       ONTIME      Closed
# 2       2025-01-01 03:30:00      OVERDUE        Open
# 3       2024-02-09 04:01:43       ONTIME      Closed
# 4       2024-02-29 08:06:25      OVERDUE      Closed
# ...                     ...          ...         ...
# 282831  2025-01-02 03:30:00      OVERDUE        Open
# 282832  2025-01-02 03:30:00      OVERDUE        Open
# 282833  2024-02-08 03:30:00       ONTIME      Closed
# 282834  2024-01-09 03:30:00      OVERDUE      Closed
# 282835  2024-10-17 04:30:00       ONTIME      Closed
#
#                                service_type  \
# 0       Improper Storage of Trash (Barrels)
# 1                          Graffiti Removal
# 2                       Parking Enforcement
# 3       Improper Storage of Trash (Barrels)
# 4                       Parking Enforcement
# ...                                     ...
# 282831                  Parking Enforcement
# 282832                  Parking Enforcement
# 282833                        CE Collection
# 282834                  Parking Enforcement
# 282835                        CE Collection
#
#                                service_name department_name     ward  \
# 0       Improper Storage of Trash (Barrels)            PWDx   Ward 1
# 1                          Graffiti Removal            PROP  Ward 16
# 2                       Parking Enforcement            BTDT  Ward 20
# 3       Improper Storage of Trash (Barrels)            PWDx   Ward 5
# 4                       Parking Enforcement            BTDT  Ward 17
# ...                                     ...             ...      ...
# 282831                  Parking Enforcement            BTDT        7
# 282832                  Parking Enforcement            BTDT   Ward 7
# 282833                        CE Collection            PWDx   Ward 4
# 282834                  Parking Enforcement            BTDT       19
# 282835                        CE Collection            PWDx        5
#
#                                street_address zipcode            latitude  \
# 0                        160-162 Liverpool St   02128   42.37387949518689
# 1                         1660 Dorchester Ave   02122  42.293928634128704
# 2                            416 Belgrade Ave   02132   42.28578965220547
# 3                          3 Saint Charles St   02116  42.347129538504745
# 4                                47 Torrey St   02124   42.28737954696088
# ...                                       ...     ...                 ...
# 282831   INTERSECTION Gold St & Dorchester St     NaN   42.33471436565981
# 282832                                49 G St   02127   42.33429950357856
# 282833                        26 Clarendon St   02116    42.3450695401875
# 282834  INTERSECTION Centre St & Burroughs St     NaN  42.311575806821814
# 282835     INTERSECTION Irving St & Revere St     NaN   42.35956847484959
#
#                  longitude    city state
# 0       -71.03980037090297  Boston    MA
# 1       -71.06182167097816  Boston    MA
# 2       -71.14928081379779  Boston    MA
# 3       -71.07181050217132  Boston    MA
# 4        -71.0735636394372  Boston    MA
# ...                    ...     ...   ...
# 282831   -71.0472890926374  Boston    MA
# 282832  -71.04438046918051  Boston    MA
# 282833   -71.0726605082934  Boston    MA
# 282834  -71.11439697757105  Boston    MA
# 282835  -71.06636036036686  Boston    MA
#
# [282836 rows x 16 columns]

# %%
dc_sub
# Out:
#             case_id       request_open_date     request_closed_date  \
# 0       24-00000013  2024/01/01 07:02:11+00  2024/01/09 19:41:49+00
# 1       24-00000033  2024/01/01 12:46:57+00  2024/01/01 12:54:05+00
# 2       24-00000045  2024/01/01 13:39:26+00  2024/01/05 13:46:58+00
# 3       24-00000046  2024/01/01 13:40:25+00  2024/01/02 15:36:35+00
# 4       24-00000059  2024/01/01 14:17:28+00  2024/01/04 12:59:13+00
# ...             ...                     ...                     ...
# 422316  24-00755508  2024/12/29 08:45:04+00  2025/02/27 17:01:22+00
# 422317  24-00619958  2024/10/19 04:10:27+00  2025/03/20 18:17:28+00
# 422318  25-00312525  2024/12/28 15:52:47+00  2025/05/22 13:46:03+00
# 422319  25-00312549  2024/04/04 13:48:29+00  2025/05/22 13:50:36+00
# 422320  25-00312503  2024/08/27 12:59:10+00  2025/05/22 13:40:44+00
#
#                  sla_target_dt           case_status  \
# 0       2024/01/10 04:59:00+00                Closed
# 1       2024/01/02 12:46:57+00                Closed
# 2       2024/01/18 13:39:26+00              Canceled
# 3       2024/01/08 13:40:25+00                Closed
# 4       2024/01/10 14:17:28+00                Closed
# ...                        ...                   ...
# 422316  2025/02/08 04:59:00+00                Closed
# 422317  2025/07/02 04:10:27+00                Closed
# 422318  2025/03/26 15:52:46+00  Closed (Transferred)
# 422319  2024/06/27 13:48:29+00  Closed (Transferred)
# 422320  2024/11/22 12:59:10+00  Closed (Transferred)
#
#                                   service_name  \
# 0                              Bulk Collection
# 1                         Traffic Safety Input
# 2       Abandoned Vehicle - On Public Property
# 3              Rodent Inspection and Treatment
# 4             Streetlight Repair Investigation
# ...                                        ...
# 422316                    Scheduled Yard Waste
# 422317                            Tree Removal
# 422318         Public Space Litter Can Removal
# 422319         Public Space Litter Can Removal
# 422320         Public Space Litter Can Removal
#
#                                              service_type department_name  \
# 0               SWMA- Solid Waste Management Admistration             DPW
# 1                            Department of Transportation            DDOT
# 2       PEMA- Parking Enforcement Management Administr...             DPW
# 3                               DOH- Department Of Health             DOH
# 4                Transportation Operations Administration            DDOT
# ...                                                   ...             ...
# 422316        SWMA- Solid Waste Management Administration             DPW
# 422317                                    Urban Forrestry            DDOT
# 422318        SWMA- Solid Waste Management Administration             DPW
# 422319        SWMA- Solid Waste Management Administration             DPW
# 422320        SWMA- Solid Waste Management Administration             DPW
#
#               city state zipcode    ward  \
# 0       WASHINGTON    DC   20011  Ward 4
# 1       WASHINGTON    DC   20011  Ward 4
# 2       WASHINGTON    DC   20019  Ward 7
# 3       WASHINGTON    DC   20019  Ward 7
# 4       WASHINGTON    DC   20011  Ward 4
# ...            ...   ...     ...     ...
# 422316  WASHINGTON    DC   20003  Ward 6
# 422317  WASHINGTON    DC   20002  Ward 5
# 422318  WASHINGTON    DC   20002  Ward 5
# 422319  WASHINGTON    DC   20009  Ward 1
# 422320  WASHINGTON    DC   20019  Ward 7
#
#                                  street_address     latitude     longitude
# 0                  5122 NEW HAMPSHIRE AVENUE NW  38.95295847   -77.0123253
# 1       13TH STREET NW AND LONGFELLOW STREET NW   38.9572776  -77.02969441
# 2                              3125 E STREET SE  38.88265423   -76.9618369
# 3                              15 53RD PLACE SE  38.88908239  -76.92509065
# 4                            5400 7TH STREET NW  38.95561809  -77.02249659
# ...                                         ...          ...           ...
# 422316                       951 14TH STREET SE  38.87881314  -76.98579088
# 422317                     1141 MORSE STREET NE  38.90409809  -76.99109961
# 422318                     1211 ORREN STREET NE  38.90243367  -76.98560506
# 422319           W STREET NW AND 12TH STREET NW  38.91918147  -77.02808424
# 422320              3306 EAST CAPITOL STREET NE  38.89009128  -76.95968759
#
# [422321 rows x 15 columns]

# %%
import pandas as pd

# Get the full set of all columns across Boston and DC.
union_cols = sorted(set(boston_sub.columns).union(dc_sub.columns))
boston_sub = boston_sub.reindex(columns=union_cols)
dc_sub     = dc_sub.reindex(columns=union_cols)

# Combine the two standardized DataFrames vertically
combined = pd.concat([boston_sub, dc_sub], axis=0, ignore_index=True)

print("Rows - Boston:", len(boston_sub))
print("Rows - DC:", len(dc_sub))
print("Rows - Combined:", len(combined))
print("Columns:", combined.shape[1])


combined.to_csv("data/staging/combined_311_staging.csv", index=False)
# Out:
# Rows - Boston: 282836
# Rows - DC: 422321
# Rows - Combined: 705157
# Columns: 16

# %%
combined.head()
print(combined.columns.tolist())
# Out:
# ['case_id', 'case_status', 'city', 'department_name', 'latitude', 'longitude', 'on_time_flag', 'request_closed_date', 'request_open_date', 'service_name', 'service_type', 'sla_target_dt', 'state', 'street_address', 'ward', 'zipcode']

# %%
combined
# Out:
#              case_id           case_status        city department_name  \
# 0       101005463183                Closed      Boston            PWDx
# 1       101005463184                Closed      Boston            PROP
# 2       101005837387                  Open      Boston            BTDT
# 3       101005287893                Closed      Boston            PWDx
# 4       101005331785                Closed      Boston            BTDT
# ...              ...                   ...         ...             ...
# 705152   24-00755508                Closed  WASHINGTON             DPW
# 705153   24-00619958                Closed  WASHINGTON            DDOT
# 705154   25-00312525  Closed (Transferred)  WASHINGTON             DPW
# 705155   25-00312549  Closed (Transferred)  WASHINGTON             DPW
# 705156   25-00312503  Closed (Transferred)  WASHINGTON             DPW
#
#                   latitude           longitude on_time_flag  \
# 0        42.37387949518689  -71.03980037090297       ONTIME
# 1       42.293928634128704  -71.06182167097816       ONTIME
# 2        42.28578965220547  -71.14928081379779      OVERDUE
# 3       42.347129538504745  -71.07181050217132       ONTIME
# 4        42.28737954696088   -71.0735636394372      OVERDUE
# ...                    ...                 ...          ...
# 705152         38.87881314        -76.98579088          NaN
# 705153         38.90409809        -76.99109961          NaN
# 705154         38.90243367        -76.98560506          NaN
# 705155         38.91918147        -77.02808424          NaN
# 705156         38.89009128        -76.95968759          NaN
#
#            request_closed_date       request_open_date  \
# 0          2024-05-15 02:58:54     2024-05-14 13:33:28
# 1          2024-05-24 12:34:37     2024-05-14 13:33:53
# 2                          NaN     2024-12-31 02:11:57
# 3          2024-02-07 05:48:33     2024-02-07 04:01:41
# 4          2024-03-04 09:07:57     2024-02-28 08:06:00
# ...                        ...                     ...
# 705152  2025/02/27 17:01:22+00  2024/12/29 08:45:04+00
# 705153  2025/03/20 18:17:28+00  2024/10/19 04:10:27+00
# 705154  2025/05/22 13:46:03+00  2024/12/28 15:52:47+00
# 705155  2025/05/22 13:50:36+00  2024/04/04 13:48:29+00
# 705156  2025/05/22 13:40:44+00  2024/08/27 12:59:10+00
#
#                                service_name  \
# 0       Improper Storage of Trash (Barrels)
# 1                          Graffiti Removal
# 2                       Parking Enforcement
# 3       Improper Storage of Trash (Barrels)
# 4                       Parking Enforcement
# ...                                     ...
# 705152                 Scheduled Yard Waste
# 705153                         Tree Removal
# 705154      Public Space Litter Can Removal
# 705155      Public Space Litter Can Removal
# 705156      Public Space Litter Can Removal
#
#                                        service_type           sla_target_dt  \
# 0               Improper Storage of Trash (Barrels)     2024-05-17 04:30:00
# 1                                  Graffiti Removal     2024-07-22 04:30:00
# 2                               Parking Enforcement     2025-01-01 03:30:00
# 3               Improper Storage of Trash (Barrels)     2024-02-09 04:01:43
# 4                               Parking Enforcement     2024-02-29 08:06:25
# ...                                             ...                     ...
# 705152  SWMA- Solid Waste Management Administration  2025/02/08 04:59:00+00
# 705153                              Urban Forrestry  2025/07/02 04:10:27+00
# 705154  SWMA- Solid Waste Management Administration  2025/03/26 15:52:46+00
# 705155  SWMA- Solid Waste Management Administration  2024/06/27 13:48:29+00
# 705156  SWMA- Solid Waste Management Administration  2024/11/22 12:59:10+00
#
#        state                  street_address     ward zipcode
# 0         MA            160-162 Liverpool St   Ward 1   02128
# 1         MA             1660 Dorchester Ave  Ward 16   02122
# 2         MA                416 Belgrade Ave  Ward 20   02132
# 3         MA              3 Saint Charles St   Ward 5   02116
# 4         MA                    47 Torrey St  Ward 17   02124
# ...      ...                             ...      ...     ...
# 705152    DC              951 14TH STREET SE   Ward 6   20003
# 705153    DC            1141 MORSE STREET NE   Ward 5   20002
# 705154    DC            1211 ORREN STREET NE   Ward 5   20002
# 705155    DC  W STREET NW AND 12TH STREET NW   Ward 1   20009
# 705156    DC     3306 EAST CAPITOL STREET NE   Ward 7   20019
#
# [705157 rows x 16 columns]

# %% [markdown]
# ## Transform

# %% [markdown]
# #### Transform Time

# %%
import pandas as pd
import re
import numpy as np

# List of datetime columns that need cleaning and standardization
cols = ["request_open_date", "request_closed_date", "sla_target_dt"]

def clean_dt(x):
    if pd.isna(x):
        return np.nan
    s = str(x).strip()
    s = re.sub(r"[\u200b\u200c\u200d\u200e\u200f\xa0\r\n\t]", "", s)  
    s = s.replace("T", " ")                                         
    s = s.split("+")[0]                                             
    s = s.replace("/", "-")                                         
    return s

for col in cols:
    combined[col] = combined[col].apply(clean_dt)
    combined[col] = pd.to_datetime(combined[col], errors="coerce")


# Use of AI
# I used ChatGPT and asked how I could convert the columns into the correct data types.
# ChatGPT then provided me with this defined function.

# %%
# check current date types
combined[cols].dtypes
# Out:
# request_open_date      datetime64[ns]
# request_closed_date    datetime64[ns]
# sla_target_dt          datetime64[ns]
# dtype: object

# %%
combined
# Out:
#              case_id           case_status        city department_name  \
# 0       101005463183                Closed      Boston            PWDx
# 1       101005463184                Closed      Boston            PROP
# 2       101005837387                  Open      Boston            BTDT
# 3       101005287893                Closed      Boston            PWDx
# 4       101005331785                Closed      Boston            BTDT
# ...              ...                   ...         ...             ...
# 705152   24-00755508                Closed  WASHINGTON             DPW
# 705153   24-00619958                Closed  WASHINGTON            DDOT
# 705154   25-00312525  Closed (Transferred)  WASHINGTON             DPW
# 705155   25-00312549  Closed (Transferred)  WASHINGTON             DPW
# 705156   25-00312503  Closed (Transferred)  WASHINGTON             DPW
#
#                   latitude           longitude on_time_flag  \
# 0        42.37387949518689  -71.03980037090297       ONTIME
# 1       42.293928634128704  -71.06182167097816       ONTIME
# 2        42.28578965220547  -71.14928081379779      OVERDUE
# 3       42.347129538504745  -71.07181050217132       ONTIME
# 4        42.28737954696088   -71.0735636394372      OVERDUE
# ...                    ...                 ...          ...
# 705152         38.87881314        -76.98579088          NaN
# 705153         38.90409809        -76.99109961          NaN
# 705154         38.90243367        -76.98560506          NaN
# 705155         38.91918147        -77.02808424          NaN
# 705156         38.89009128        -76.95968759          NaN
#
#        request_closed_date   request_open_date  \
# 0      2024-05-15 02:58:54 2024-05-14 13:33:28
# 1      2024-05-24 12:34:37 2024-05-14 13:33:53
# 2                      NaT 2024-12-31 02:11:57
# 3      2024-02-07 05:48:33 2024-02-07 04:01:41
# 4      2024-03-04 09:07:57 2024-02-28 08:06:00
# ...                    ...                 ...
# 705152 2025-02-27 17:01:22 2024-12-29 08:45:04
# 705153 2025-03-20 18:17:28 2024-10-19 04:10:27
# 705154 2025-05-22 13:46:03 2024-12-28 15:52:47
# 705155 2025-05-22 13:50:36 2024-04-04 13:48:29
# 705156 2025-05-22 13:40:44 2024-08-27 12:59:10
#
#                                service_name  \
# 0       Improper Storage of Trash (Barrels)
# 1                          Graffiti Removal
# 2                       Parking Enforcement
# 3       Improper Storage of Trash (Barrels)
# 4                       Parking Enforcement
# ...                                     ...
# 705152                 Scheduled Yard Waste
# 705153                         Tree Removal
# 705154      Public Space Litter Can Removal
# 705155      Public Space Litter Can Removal
# 705156      Public Space Litter Can Removal
#
#                                        service_type       sla_target_dt state  \
# 0               Improper Storage of Trash (Barrels) 2024-05-17 04:30:00    MA
# 1                                  Graffiti Removal 2024-07-22 04:30:00    MA
# 2                               Parking Enforcement 2025-01-01 03:30:00    MA
# 3               Improper Storage of Trash (Barrels) 2024-02-09 04:01:43    MA
# 4                               Parking Enforcement 2024-02-29 08:06:25    MA
# ...                                             ...                 ...   ...
# 705152  SWMA- Solid Waste Management Administration 2025-02-08 04:59:00    DC
# 705153                              Urban Forrestry 2025-07-02 04:10:27    DC
# 705154  SWMA- Solid Waste Management Administration 2025-03-26 15:52:46    DC
# 705155  SWMA- Solid Waste Management Administration 2024-06-27 13:48:29    DC
# 705156  SWMA- Solid Waste Management Administration 2024-11-22 12:59:10    DC
#
#                         street_address     ward zipcode
# 0                 160-162 Liverpool St   Ward 1   02128
# 1                  1660 Dorchester Ave  Ward 16   02122
# 2                     416 Belgrade Ave  Ward 20   02132
# 3                   3 Saint Charles St   Ward 5   02116
# 4                         47 Torrey St  Ward 17   02124
# ...                                ...      ...     ...
# 705152              951 14TH STREET SE   Ward 6   20003
# 705153            1141 MORSE STREET NE   Ward 5   20002
# 705154            1211 ORREN STREET NE   Ward 5   20002
# 705155  W STREET NW AND 12TH STREET NW   Ward 1   20009
# 705156     3306 EAST CAPITOL STREET NE   Ward 7   20019
#
# [705157 rows x 16 columns]

# %% [markdown]
# #### Create resolution_days

# %%
from sqlalchemy import text

# Create the resolution_rules table if it does not exist
with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS config.resolution_rules (
            state TEXT,
            open_col TEXT,
            closed_col TEXT,
            output_col TEXT
        );
    """))
# Clear old rules to avoid duplicates
with engine.begin() as conn:
    conn.execute(text("DELETE FROM config.resolution_rules;"))

# Insert the resolution rules for MA and DC
with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO config.resolution_rules VALUES
        ('MA', 'request_open_date', 'request_closed_date', 'resolution_days'),
        ('DC', 'request_open_date', 'request_closed_date', 'resolution_days');
    """))

# Apply each rule from the table to the combined dataset
for _, rule in res_rules.iterrows():
    combined = apply_resolution_days(combined, rule)


res_rules = pd.read_sql("SELECT * FROM config.resolution_rules", engine)
res_rules
# Out:
#   state           open_col           closed_col       output_col
# 0    MA  request_open_date  request_closed_date  resolution_days
# 1    DC  request_open_date  request_closed_date  resolution_days

# %%
def apply_resolution_days(df, rule):
    # Extract rule fields from the configuration row
    state = rule["state"]
    open_col = rule["open_col"]
    closed_col = rule["closed_col"]
    output_col = rule["output_col"]

    # Filter rows that belong to the target state
    mask = df["state"] == state

    # Identify rows where both open + closed dates exist (not null)
    has_both = df.loc[mask, open_col].notna() & df.loc[mask, closed_col].notna()

    # Normalize timestamps into pure dates (drop time component)
    open_d = df.loc[mask & has_both, open_col].dt.normalize()
    close_d = df.loc[mask & has_both, closed_col].dt.normalize()

    # Compute resolution days: closed_date - open_date
    df.loc[mask & has_both, output_col] = (close_d - open_d).dt.days

    return df
    
# Use of Ai
# I also asked ChatGPT to teach me how to define a function, what components it should include, 
# and how to integrate those elements with the code I had already written below.

# %% [raw]
# # check if both two columns have values
# check_null = combined["request_closed_date"].notna() & combined["request_open_date"].notna()
#
# # removes the time portion, comparing only the date
# open_d = combined.loc[check_null, "request_closed_date"].dt.normalize()
# close_d = combined.loc[check_null, "request_open_date"].dt.normalize()
#
# combined.loc[check_null, "resolution_days"] = (open_d - close_d).dt.days
#
# # I asked Google what to do if I want to check whether two columns have values in Python, and it taught me to use .notna()

# %%
combined
# Out:
#              case_id           case_status        city department_name  \
# 0       101005463183                Closed      Boston            PWDx
# 1       101005463184                Closed      Boston            PROP
# 2       101005837387                  Open      Boston            BTDT
# 3       101005287893                Closed      Boston            PWDx
# 4       101005331785                Closed      Boston            BTDT
# ...              ...                   ...         ...             ...
# 705152   24-00755508                Closed  WASHINGTON             DPW
# 705153   24-00619958                Closed  WASHINGTON            DDOT
# 705154   25-00312525  Closed (Transferred)  WASHINGTON             DPW
# 705155   25-00312549  Closed (Transferred)  WASHINGTON             DPW
# 705156   25-00312503  Closed (Transferred)  WASHINGTON             DPW
#
#                   latitude           longitude on_time_flag  \
# 0        42.37387949518689  -71.03980037090297       ONTIME
# 1       42.293928634128704  -71.06182167097816       ONTIME
# 2        42.28578965220547  -71.14928081379779      OVERDUE
# 3       42.347129538504745  -71.07181050217132       ONTIME
# 4        42.28737954696088   -71.0735636394372      OVERDUE
# ...                    ...                 ...          ...
# 705152         38.87881314        -76.98579088          NaN
# 705153         38.90409809        -76.99109961          NaN
# 705154         38.90243367        -76.98560506          NaN
# 705155         38.91918147        -77.02808424          NaN
# 705156         38.89009128        -76.95968759          NaN
#
#        request_closed_date   request_open_date  \
# 0      2024-05-15 02:58:54 2024-05-14 13:33:28
# 1      2024-05-24 12:34:37 2024-05-14 13:33:53
# 2                      NaT 2024-12-31 02:11:57
# 3      2024-02-07 05:48:33 2024-02-07 04:01:41
# 4      2024-03-04 09:07:57 2024-02-28 08:06:00
# ...                    ...                 ...
# 705152 2025-02-27 17:01:22 2024-12-29 08:45:04
# 705153 2025-03-20 18:17:28 2024-10-19 04:10:27
# 705154 2025-05-22 13:46:03 2024-12-28 15:52:47
# 705155 2025-05-22 13:50:36 2024-04-04 13:48:29
# 705156 2025-05-22 13:40:44 2024-08-27 12:59:10
#
#                                service_name  \
# 0       Improper Storage of Trash (Barrels)
# 1                          Graffiti Removal
# 2                       Parking Enforcement
# 3       Improper Storage of Trash (Barrels)
# 4                       Parking Enforcement
# ...                                     ...
# 705152                 Scheduled Yard Waste
# 705153                         Tree Removal
# 705154      Public Space Litter Can Removal
# 705155      Public Space Litter Can Removal
# 705156      Public Space Litter Can Removal
#
#                                        service_type       sla_target_dt state  \
# 0               Improper Storage of Trash (Barrels) 2024-05-17 04:30:00    MA
# 1                                  Graffiti Removal 2024-07-22 04:30:00    MA
# 2                               Parking Enforcement 2025-01-01 03:30:00    MA
# 3               Improper Storage of Trash (Barrels) 2024-02-09 04:01:43    MA
# 4                               Parking Enforcement 2024-02-29 08:06:25    MA
# ...                                             ...                 ...   ...
# 705152  SWMA- Solid Waste Management Administration 2025-02-08 04:59:00    DC
# 705153                              Urban Forrestry 2025-07-02 04:10:27    DC
# 705154  SWMA- Solid Waste Management Administration 2025-03-26 15:52:46    DC
# 705155  SWMA- Solid Waste Management Administration 2024-06-27 13:48:29    DC
# 705156  SWMA- Solid Waste Management Administration 2024-11-22 12:59:10    DC
#
#                         street_address     ward zipcode  resolution_days
# 0                 160-162 Liverpool St   Ward 1   02128              1.0
# 1                  1660 Dorchester Ave  Ward 16   02122             10.0
# 2                     416 Belgrade Ave  Ward 20   02132              NaN
# 3                   3 Saint Charles St   Ward 5   02116              0.0
# 4                         47 Torrey St  Ward 17   02124              5.0
# ...                                ...      ...     ...              ...
# 705152              951 14TH STREET SE   Ward 6   20003             60.0
# 705153            1141 MORSE STREET NE   Ward 5   20002            152.0
# 705154            1211 ORREN STREET NE   Ward 5   20002            145.0
# 705155  W STREET NW AND 12TH STREET NW   Ward 1   20009            413.0
# 705156     3306 EAST CAPITOL STREET NE   Ward 7   20019            268.0
#
# [705157 rows x 17 columns]

# %% [markdown]
# #### Fill in DC’s on_time_flag

# %%
from sqlalchemy import create_engine, text


engine = create_engine(f"postgresql://postgres:Chaney0616%%%@localhost:5432/Term_Project")

from sqlalchemy import text

# Create the schema "config" if it does not already exist
with engine.begin() as conn:
    conn.execute(text("""
        CREATE SCHEMA IF NOT EXISTS config;
    """))

with engine.begin() as conn:
    conn.execute(text("DROP TABLE IF EXISTS config.on_time_rules;"))

with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE config.on_time_rules (
            state TEXT,
            closed_col TEXT,
            target_col TEXT,
            status_ontime TEXT,
            status_overdue TEXT,
            status_unknown TEXT
        );
    """))

# %%
# Clear old rules
with engine.begin() as conn:
    conn.execute(text("DELETE FROM config.on_time_rules;"))

# Insert new rules for MA and DC
with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO config.on_time_rules (state, closed_col, target_col, status_ontime, status_overdue, status_unknown)
        VALUES
        ('MA', 'request_closed_date', 'sla_target_dt', 'ONTIME', 'OVERDUE', 'UNKNOWN'),
        ('DC', 'request_closed_date', 'sla_target_dt', 'ONTIME', 'OVERDUE', 'UNKNOWN');
    """))

rules = pd.read_sql("SELECT * FROM config.on_time_rules", engine)
rules
# Out:
#   state           closed_col     target_col status_ontime status_overdue  \
# 0    MA  request_closed_date  sla_target_dt        ONTIME        OVERDUE
# 1    DC  request_closed_date  sla_target_dt        ONTIME        OVERDUE
#
#   status_unknown
# 0        UNKNOWN
# 1        UNKNOWN

# %%
def auto_on_time_flag(df):
    # Loop through each state in the dataset
    for st in df['state'].unique():
        mask = df['state'] == st

        has_both = df.loc[mask, 'request_closed_date'].notna() & df.loc[mask, 'sla_target_dt'].notna()
        
        # Assign ONTIME or OVERDUE only to rows where both dates exist
        df.loc[mask & has_both, "on_time_flag"] = np.where(
            df.loc[mask & has_both, 'request_closed_date'] <= df.loc[mask & has_both, 'sla_target_dt'],
            "ONTIME",
            "OVERDUE"
        )
        # If a row is missing one or both dates → mark as UNKNOWN
        df.loc[mask & ~has_both, "on_time_flag"] = "UNKNOWN"

    return df


# I used ChatGPT to help me design the logic for defining a reusable function that automatically 
# assigns the on_time_flag based on the closed date and SLA target date.

# %% [raw]
# import numpy as np
#
# # only compute for DC rows
# mask = combined["state"] == "DC"
#
# # check if both two columns have values
# check = combined["request_closed_date"].notna() & combined["sla_target_dt"].notna()
#
# # computed ONTIME / OVERDUE
# combined.loc[mask & check, "on_time_flag"] = np.where(
#     combined.loc[mask & check, "request_closed_date"]
#     <= combined.loc[mask & check, "sla_target_dt"],
#     "ONTIME",
#     "OVERDUE"
# )
#
# combined.loc[mask & ~check, "on_time_flag"] = "UNKNOWN"

# %%
combined = auto_on_time_flag(combined)

combined.loc[combined["state"] == "DC", ["city", "on_time_flag"]].head(20)
# Out:
#               city on_time_flag
# 282836  WASHINGTON       ONTIME
# 282837  WASHINGTON       ONTIME
# 282838  WASHINGTON       ONTIME
# 282839  WASHINGTON       ONTIME
# 282840  WASHINGTON       ONTIME
# 282841  WASHINGTON       ONTIME
# 282842  WASHINGTON      OVERDUE
# 282843  WASHINGTON       ONTIME
# 282844  WASHINGTON       ONTIME
# 282845  WASHINGTON       ONTIME
# 282846  WASHINGTON       ONTIME
# 282847  WASHINGTON       ONTIME
# 282848  WASHINGTON       ONTIME
# 282849  WASHINGTON      OVERDUE
# 282850  WASHINGTON       ONTIME
# 282851  WASHINGTON       ONTIME
# 282852  WASHINGTON      OVERDUE
# 282853  WASHINGTON       ONTIME
# 282854  WASHINGTON       ONTIME
# 282855  WASHINGTON       ONTIME

# %% [markdown]
# #### Data Quality Screening

# %%
# check if there is any null value 

null_value = combined.isnull().sum().sort_values(ascending = False)
null_value
# Out:
# zipcode                61283
# resolution_days        44651
# request_closed_date    44651
# service_type           23296
# sla_target_dt          22995
# street_address          3611
# latitude                2158
# longitude               2158
# ward                      93
# service_name              89
# department_name           37
# state                      0
# case_id                    0
# case_status                0
# on_time_flag               0
# city                       0
# request_open_date          0
# dtype: int64

# %%
# check if there is any closed date earlier than open date 

invalid_close = combined[combined['request_closed_date'] < combined['request_open_date']]

print("Invalid count:" , len(invalid_close))
invalid_close.head()
# Out:
# Invalid count: 1
#              case_id case_status    city department_name           latitude  \
# 105120  101005756692      Closed  Boston            PWDx  42.34359821254504
#
#                  longitude on_time_flag request_closed_date  \
# 105120  -71.07231656543824       ONTIME 2024-11-03 01:01:55
#
#          request_open_date         service_name         service_type  \
# 105120 2024-11-03 01:44:58  Empty Litter Basket  Empty Litter Basket
#
#              sla_target_dt state                        street_address ward  \
# 105120 2024-11-05 03:30:00    MA  INTERSECTION Union Park & Tremont St    3
#
#        zipcode  resolution_days
# 105120     NaN              0.0

# %%
# check if there is any target date earlier than open date 

invalid_sla = combined[combined['sla_target_dt'] < combined['request_open_date']]

print("Invalid count:" , len(invalid_sla))
invalid_sla.head()
# Out:
# Invalid count: 0
# Empty DataFrame
# Columns: [case_id, case_status, city, department_name, latitude, longitude, on_time_flag, request_closed_date, request_open_date, service_name, service_type, sla_target_dt, state, street_address, ward, zipcode, resolution_days]
# Index: []

# %%
# check if there is any invalid resolution days

negative_days = combined[combined['resolution_days'] < 0]

print("Negative count:", len(negative_days))



# extremely large resolution days 
large_days = combined[(combined['resolution_days'].notna()) & (combined['resolution_days'] > 365)]

print("Large days count:", len(large_days))


# closed cases should not have NULL resolution_days
closed_null_res = combined[(combined['case_status'] == "Closed") & (combined['resolution_days'].isna())]

print("Closed cases with NULL resolution_days:", len(closed_null_res))


# I have ask ChatGPT what other conditions can be tested here other than negative day. 
# And it suggested me to check extremely large resolution days and Closed cases should not have NULL resolution_days
# Out:
# Negative count: 0
# Large days count: 1245
# Closed cases with NULL resolution_days: 0

# %%
# Geographic Outliers
# According to Google: Boston's land area spans from approximately 42.21° N to 42.36° N in latitude and -71.05° W to - 71.01° W in longitude


# Ensure latitude and longitude are numeric before geographic checks
combined['latitude'] = pd.to_numeric(combined['latitude'], errors='coerce')
combined['longitude'] = pd.to_numeric(combined['longitude'], errors='coerce')


boston = combined[combined['city'] == "Boston"]

# Boston latitude out of range
boston_lat_out = boston[(boston['latitude'].notna()) & ((boston['latitude'] < 42.20) | (boston['latitude'] > 42.40))]

print("Boston invalid latitude:", len(boston_lat_out))
boston_lat_out.head()


boston_lng_out = boston[(boston['longitude'].notna()) & ((boston['longitude'] < -71.20) | (boston['longitude'] > -70.90))]

print("Boston invalid longitude:", len(boston_lng_out))
boston_lng_out.head()
# Out:
# Boston invalid latitude: 0
# Boston invalid longitude: 0
# Empty DataFrame
# Columns: [case_id, case_status, city, department_name, latitude, longitude, on_time_flag, request_closed_date, request_open_date, service_name, service_type, sla_target_dt, state, street_address, ward, zipcode, resolution_days]
# Index: []

# %%
# Geographic Outliers
# According to Google: Washington, D.C. is approximately at a latitude of 38.8951 N° and a longitude of -77.0364° W 


# DC geographic outliers

dc = combined[combined['city'] == "Washington"]

# DC latitude out of range
dc_lat_out = dc[(dc['latitude'].notna()) & ((dc['latitude'] < 38.80) | (dc['latitude'] > 39.05))]

print("DC invalid latitude:", len(dc_lat_out))
dc_lat_out.head()


# DC longitude out of range
dc_lng_out = dc[(dc['longitude'].notna()) & ((dc['longitude'] < -77.20) | (dc['longitude'] > -76.80))]

print("DC invalid longitude:", len(dc_lng_out))
dc_lng_out.head()
# Out:
# DC invalid latitude: 0
# DC invalid longitude: 0
# Empty DataFrame
# Columns: [case_id, case_status, city, department_name, latitude, longitude, on_time_flag, request_closed_date, request_open_date, service_name, service_type, sla_target_dt, state, street_address, ward, zipcode, resolution_days]
# Index: []

# %% [markdown]
# #### Data Cleaning

# %%
# Function to print categorical value counts
def show_categorical_counts(df, df_name, col):

    print(f"\n{df_name} – {col}")
    counts = df[col].value_counts(dropna=False)
    print(counts)
    print(f"Total unique: {counts.shape[0]}")


# Filter to only include DC rows
dc = combined[combined['city'] == "WASHINGTON"]

print("DC Categorical Check:\n")

# Check only the two columns you asked for
show_categorical_counts(dc, "DC", "case_status")
show_categorical_counts(dc, "DC", "ward")
# Out:
# DC Categorical Check:
#
#
# DC – case_status
# case_status
# Closed                  402432
# Closed (Duplicate)       11995
# Canceled                  3086
# In-Progress               2165
# Open                      1619
# Closed (Transferred)       959
# Open (Duplicate)            53
# In Progress                 10
# Canceled (Duplicate)         2
# Name: count, dtype: int64
# Total unique: 9
#
# DC – ward
# ward
# Ward 6    71255
# Ward 5    63255
# Ward 4    61474
# Ward 1    51545
# Ward 7    49513
# Ward 2    43474
# Ward 8    43187
# Ward 3    36850
# Null       1675
# NaN          93
# Name: count, dtype: int64
# Total unique: 10

# %%
from sqlalchemy import text

# 1. Create the table if needed
with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS config.case_status_rules (
            raw_value TEXT,
            unified_value TEXT
        );
    """))

# 2. Clear old rules
with engine.begin() as conn:
    conn.execute(text("DELETE FROM config.case_status_rules;"))

# 3. Insert unified mapping rules  
with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO config.case_status_rules (raw_value, unified_value) VALUES
            ('Closed', 'Closed'),
            ('Closed (Duplicate)', 'Closed'),
            ('Closed (Transferred)', 'Closed'),

            ('Open', 'Open'),
            ('Open (Duplicate)', 'Open'),

            ('In Progress', 'Closed'),
            ('In-Progress', 'Closed'),

            ('Canceled', 'Closed'),
            ('Canceled (Duplicate)', 'Closed');
    """))

# 4. Load rules into pandas
case_rules = pd.read_sql("SELECT * FROM config.case_status_rules", engine)
case_rules
# Out:
#               raw_value unified_value
# 0                Closed        Closed
# 1    Closed (Duplicate)        Closed
# 2  Closed (Transferred)        Closed
# 3                  Open          Open
# 4      Open (Duplicate)          Open
# 5           In Progress        Closed
# 6           In-Progress        Closed
# 7              Canceled        Closed
# 8  Canceled (Duplicate)        Closed

# %%
def apply_case_status_clean(df):


    # Convert rules to dictionary: raw to unified
    mapping = dict(zip(case_rules['raw_value'], case_rules['unified_value']))

    # Apply mapping
    df['case_status_clean'] = df['case_status'].map(mapping)

    # Handle unexpected values
    df['case_status_clean'] = df['case_status_clean'].fillna('Unknown')

    return df

combined = apply_case_status_clean(combined)
combined[['city', 'case_status', 'case_status_clean']].tail(10)
# Out:
#               city           case_status case_status_clean
# 705147  WASHINGTON                Closed            Closed
# 705148  WASHINGTON                Closed            Closed
# 705149  WASHINGTON  Closed (Transferred)            Closed
# 705150  WASHINGTON                Closed            Closed
# 705151  WASHINGTON  Closed (Transferred)            Closed
# 705152  WASHINGTON                Closed            Closed
# 705153  WASHINGTON                Closed            Closed
# 705154  WASHINGTON  Closed (Transferred)            Closed
# 705155  WASHINGTON  Closed (Transferred)            Closed
# 705156  WASHINGTON  Closed (Transferred)            Closed

# %%
combined
# Out:
#              case_id           case_status        city department_name  \
# 0       101005463183                Closed      Boston            PWDx
# 1       101005463184                Closed      Boston            PROP
# 2       101005837387                  Open      Boston            BTDT
# 3       101005287893                Closed      Boston            PWDx
# 4       101005331785                Closed      Boston            BTDT
# ...              ...                   ...         ...             ...
# 705152   24-00755508                Closed  WASHINGTON             DPW
# 705153   24-00619958                Closed  WASHINGTON            DDOT
# 705154   25-00312525  Closed (Transferred)  WASHINGTON             DPW
# 705155   25-00312549  Closed (Transferred)  WASHINGTON             DPW
# 705156   25-00312503  Closed (Transferred)  WASHINGTON             DPW
#
#          latitude  longitude on_time_flag request_closed_date  \
# 0       42.373879 -71.039800       ONTIME 2024-05-15 02:58:54
# 1       42.293929 -71.061822       ONTIME 2024-05-24 12:34:37
# 2       42.285790 -71.149281      UNKNOWN                 NaT
# 3       42.347130 -71.071811       ONTIME 2024-02-07 05:48:33
# 4       42.287380 -71.073564      OVERDUE 2024-03-04 09:07:57
# ...           ...        ...          ...                 ...
# 705152  38.878813 -76.985791      OVERDUE 2025-02-27 17:01:22
# 705153  38.904098 -76.991100       ONTIME 2025-03-20 18:17:28
# 705154  38.902434 -76.985605      OVERDUE 2025-05-22 13:46:03
# 705155  38.919181 -77.028084      OVERDUE 2025-05-22 13:50:36
# 705156  38.890091 -76.959688      OVERDUE 2025-05-22 13:40:44
#
#          request_open_date                         service_name  \
# 0      2024-05-14 13:33:28  Improper Storage of Trash (Barrels)
# 1      2024-05-14 13:33:53                     Graffiti Removal
# 2      2024-12-31 02:11:57                  Parking Enforcement
# 3      2024-02-07 04:01:41  Improper Storage of Trash (Barrels)
# 4      2024-02-28 08:06:00                  Parking Enforcement
# ...                    ...                                  ...
# 705152 2024-12-29 08:45:04                 Scheduled Yard Waste
# 705153 2024-10-19 04:10:27                         Tree Removal
# 705154 2024-12-28 15:52:47      Public Space Litter Can Removal
# 705155 2024-04-04 13:48:29      Public Space Litter Can Removal
# 705156 2024-08-27 12:59:10      Public Space Litter Can Removal
#
#                                        service_type       sla_target_dt state  \
# 0               Improper Storage of Trash (Barrels) 2024-05-17 04:30:00    MA
# 1                                  Graffiti Removal 2024-07-22 04:30:00    MA
# 2                               Parking Enforcement 2025-01-01 03:30:00    MA
# 3               Improper Storage of Trash (Barrels) 2024-02-09 04:01:43    MA
# 4                               Parking Enforcement 2024-02-29 08:06:25    MA
# ...                                             ...                 ...   ...
# 705152  SWMA- Solid Waste Management Administration 2025-02-08 04:59:00    DC
# 705153                              Urban Forrestry 2025-07-02 04:10:27    DC
# 705154  SWMA- Solid Waste Management Administration 2025-03-26 15:52:46    DC
# 705155  SWMA- Solid Waste Management Administration 2024-06-27 13:48:29    DC
# 705156  SWMA- Solid Waste Management Administration 2024-11-22 12:59:10    DC
#
#                         street_address     ward zipcode  resolution_days  \
# 0                 160-162 Liverpool St   Ward 1   02128              1.0
# 1                  1660 Dorchester Ave  Ward 16   02122             10.0
# 2                     416 Belgrade Ave  Ward 20   02132              NaN
# 3                   3 Saint Charles St   Ward 5   02116              0.0
# 4                         47 Torrey St  Ward 17   02124              5.0
# ...                                ...      ...     ...              ...
# 705152              951 14TH STREET SE   Ward 6   20003             60.0
# 705153            1141 MORSE STREET NE   Ward 5   20002            152.0
# 705154            1211 ORREN STREET NE   Ward 5   20002            145.0
# 705155  W STREET NW AND 12TH STREET NW   Ward 1   20009            413.0
# 705156     3306 EAST CAPITOL STREET NE   Ward 7   20019            268.0
#
#        case_status_clean
# 0                 Closed
# 1                 Closed
# 2                   Open
# 3                 Closed
# 4                 Closed
# ...                  ...
# 705152            Closed
# 705153            Closed
# 705154            Closed
# 705155            Closed
# 705156            Closed
#
# [705157 rows x 18 columns]

# %% [raw]
# # Clean DC case_status into a unified field
#
# case_status_mapping = {
#     "Closed (Duplicate)": "Closed",
#     "Closed (Transferred)": "Closed",
#     "Closed": "Closed",
#     "Open (Duplicate)": "Open",
#     "Open": "Open",
#     "In-Progress": "In Progress",
#     "In Progress": "In Progress",
#     "Canceled": "Canceled",
#     "Canceled (Duplicate)": "Canceled"
# }
#
# # create new clean column
# combined['case_status_clean'] = combined['case_status'].map(case_status_mapping)
#
# # dect any unexpected values
# unexpected = combined[combined['case_status_clean'].isna()]['case_status'].unique()
# print("Unexpected case_status values:", unexpected)
#
# # fill unexpected with "Unknown"
# combined['case_status_clean'] = combined['case_status_clean'].fillna('Unknown')
#
# # show last rows to verify
# combined[['city', 'case_status', 'case_status_clean']].tail(20)
#
#
#
# # Use of AI:
# # I asked ChatGPT to review my approach for cleaning the case_status field.
# # ChatGPT explained that in standard ETL pipelines (industry practice),
# # we usually DO NOT overwrite the original raw column directly.
# # Instead, we create a new cleaned version (e.g., case_status_clean).
# # This approach preserves the original data for traceability,
# # avoids losing information, and makes downstream dimensional modeling easier.
# # Based on this feedback, I decided to create a new column 'case_status_clean'
# # instead of modifying 'case_status' directly.

# %%
# Fill missing categorical values with 'Unknown'

# service_type (
combined['service_type_clean'] = combined['service_type'].fillna('Unknown')

# ward
combined['ward_clean'] = combined['ward'].replace(['Null'], pd.NA).fillna('Unknown')

# department 
combined['department_clean'] = combined['department_name'].fillna('Unknown')

# street address 
combined['street_address_clean'] = combined['street_address'].fillna('Unknown')

# zipcode 
combined['zipcode_clean'] = combined['zipcode'].fillna('Unknown')

# %%
combined[combined['ward'].isna()][['ward', 'ward_clean']].head()
combined[combined['service_type'].isna()][['service_type','service_type_clean']].head()
combined[combined['street_address'].isna()][['street_address','street_address_clean']].head()
# Out:
#     street_address street_address_clean
# 160            NaN              Unknown
# 377            NaN              Unknown
# 420            NaN              Unknown
# 581            NaN              Unknown
# 589            NaN              Unknown

# %%
combined
# Out:
#              case_id           case_status        city department_name  \
# 0       101005463183                Closed      Boston            PWDx
# 1       101005463184                Closed      Boston            PROP
# 2       101005837387                  Open      Boston            BTDT
# 3       101005287893                Closed      Boston            PWDx
# 4       101005331785                Closed      Boston            BTDT
# ...              ...                   ...         ...             ...
# 705152   24-00755508                Closed  WASHINGTON             DPW
# 705153   24-00619958                Closed  WASHINGTON            DDOT
# 705154   25-00312525  Closed (Transferred)  WASHINGTON             DPW
# 705155   25-00312549  Closed (Transferred)  WASHINGTON             DPW
# 705156   25-00312503  Closed (Transferred)  WASHINGTON             DPW
#
#          latitude  longitude on_time_flag request_closed_date  \
# 0       42.373879 -71.039800       ONTIME 2024-05-15 02:58:54
# 1       42.293929 -71.061822       ONTIME 2024-05-24 12:34:37
# 2       42.285790 -71.149281      UNKNOWN                 NaT
# 3       42.347130 -71.071811       ONTIME 2024-02-07 05:48:33
# 4       42.287380 -71.073564      OVERDUE 2024-03-04 09:07:57
# ...           ...        ...          ...                 ...
# 705152  38.878813 -76.985791      OVERDUE 2025-02-27 17:01:22
# 705153  38.904098 -76.991100       ONTIME 2025-03-20 18:17:28
# 705154  38.902434 -76.985605      OVERDUE 2025-05-22 13:46:03
# 705155  38.919181 -77.028084      OVERDUE 2025-05-22 13:50:36
# 705156  38.890091 -76.959688      OVERDUE 2025-05-22 13:40:44
#
#          request_open_date                         service_name  ...  \
# 0      2024-05-14 13:33:28  Improper Storage of Trash (Barrels)  ...
# 1      2024-05-14 13:33:53                     Graffiti Removal  ...
# 2      2024-12-31 02:11:57                  Parking Enforcement  ...
# 3      2024-02-07 04:01:41  Improper Storage of Trash (Barrels)  ...
# 4      2024-02-28 08:06:00                  Parking Enforcement  ...
# ...                    ...                                  ...  ...
# 705152 2024-12-29 08:45:04                 Scheduled Yard Waste  ...
# 705153 2024-10-19 04:10:27                         Tree Removal  ...
# 705154 2024-12-28 15:52:47      Public Space Litter Can Removal  ...
# 705155 2024-04-04 13:48:29      Public Space Litter Can Removal  ...
# 705156 2024-08-27 12:59:10      Public Space Litter Can Removal  ...
#
#                         street_address     ward zipcode resolution_days  \
# 0                 160-162 Liverpool St   Ward 1   02128             1.0
# 1                  1660 Dorchester Ave  Ward 16   02122            10.0
# 2                     416 Belgrade Ave  Ward 20   02132             NaN
# 3                   3 Saint Charles St   Ward 5   02116             0.0
# 4                         47 Torrey St  Ward 17   02124             5.0
# ...                                ...      ...     ...             ...
# 705152              951 14TH STREET SE   Ward 6   20003            60.0
# 705153            1141 MORSE STREET NE   Ward 5   20002           152.0
# 705154            1211 ORREN STREET NE   Ward 5   20002           145.0
# 705155  W STREET NW AND 12TH STREET NW   Ward 1   20009           413.0
# 705156     3306 EAST CAPITOL STREET NE   Ward 7   20019           268.0
#
#        case_status_clean                           service_type_clean  \
# 0                 Closed          Improper Storage of Trash (Barrels)
# 1                 Closed                             Graffiti Removal
# 2                   Open                          Parking Enforcement
# 3                 Closed          Improper Storage of Trash (Barrels)
# 4                 Closed                          Parking Enforcement
# ...                  ...                                          ...
# 705152            Closed  SWMA- Solid Waste Management Administration
# 705153            Closed                              Urban Forrestry
# 705154            Closed  SWMA- Solid Waste Management Administration
# 705155            Closed  SWMA- Solid Waste Management Administration
# 705156            Closed  SWMA- Solid Waste Management Administration
#
#         ward_clean department_clean            street_address_clean  \
# 0           Ward 1             PWDx            160-162 Liverpool St
# 1          Ward 16             PROP             1660 Dorchester Ave
# 2          Ward 20             BTDT                416 Belgrade Ave
# 3           Ward 5             PWDx              3 Saint Charles St
# 4          Ward 17             BTDT                    47 Torrey St
# ...            ...              ...                             ...
# 705152      Ward 6              DPW              951 14TH STREET SE
# 705153      Ward 5             DDOT            1141 MORSE STREET NE
# 705154      Ward 5              DPW            1211 ORREN STREET NE
# 705155      Ward 1              DPW  W STREET NW AND 12TH STREET NW
# 705156      Ward 7              DPW     3306 EAST CAPITOL STREET NE
#
#        zipcode_clean
# 0              02128
# 1              02122
# 2              02132
# 3              02116
# 4              02124
# ...              ...
# 705152         20003
# 705153         20002
# 705154         20002
# 705155         20009
# 705156         20019
#
# [705157 rows x 23 columns]

# %%
# Check if case_id has any NULL values
print("NULL case_id:", combined['case_id'].isna().sum())

# Check for duplicate case_id values
dup_ids = (
    combined[combined['case_id'].duplicated(keep=False)]
    [['case_id', 'city', 'request_open_date', 'service_name']]
    .sort_values('case_id')
)

print("Duplicate case_id rows:", len(dup_ids))
dup_ids.head(10)
# Out:
# NULL case_id: 0
# Duplicate case_id rows: 0
# Empty DataFrame
# Columns: [case_id, city, request_open_date, service_name]
# Index: []

# %%
combined.to_csv("combined_clean1.csv", index=False)

# %%
print("\nColumn Names:")
print(combined.columns.tolist())
# Out:
# Column Names:
# ['case_id', 'case_status', 'city', 'department_name', 'latitude', 'longitude', 'on_time_flag', 'request_closed_date', 'request_open_date', 'service_name', 'service_type', 'sla_target_dt', 'state', 'street_address', 'ward', 'zipcode', 'resolution_days', 'case_status_clean', 'service_type_clean', 'ward_clean', 'department_clean', 'street_address_clean', 'zipcode_clean']
